# %% [markdown]
# # 17.1 使用Web API

# %% [markdown]
# ## 17.1.4 处理API响应

# %%
import requests

# 定义API URL
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

try:
    # 执行API调用
    response = requests.get(url)
    # 确保请求成功
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    # 如果请求发生错误，打印错误信息
    print(f"请求错误: {e}")
else:
    # 将API响应存储为JSON格式
    response_dict = response.json()
    
    # 打印状态码和响应中包含的键
    print(f"Status code: {response.status_code}")
    print("Response keys:", response_dict.keys())
    
    # 检查并处理结果项
    items = response_dict.get('items', [])
    if items:
        # 打印第一个仓库的基本信息作为示例
        first_repo = items[0]
        print("\nFirst repository information:")
        print(f"Name: {first_repo['name']}")
        print(f"Owner: {first_repo['owner']['login']}")
        print(f"Stars: {first_repo['stargazers_count']}")
        print(f"Repository URL: {first_repo['html_url']}")
    else:
        print("No repositories found.")
# Out:
# Status code: 200
# Response keys: dict_keys(['total_count', 'incomplete_results', 'items'])
#
# First repository information:
# Name: public-apis
# Owner: public-apis
# Stars: 295536
# Repository URL: https://github.com/public-apis/public-apis

# %% [markdown]
# ## 17.1.5 处理响应字典

# %%
import requests

# 定义API URL和查询参数
url = 'https://api.github.com/search/repositories'
params = {
    'q': 'language:python',
    'sort': 'stars',
    'per_page': 10  # 可选，限制返回的仓库数量，提高演示效率
}

try:
    # 执行API调用
    response = requests.get(url, params=params)
    response.raise_for_status()  # 检查请求是否成功
except requests.RequestException as e:
    print(f"请求错误: {e}")
else:
    # 解析JSON响应
    response_dict = response.json()
    print(f"状态码: {response.status_code}")
    print(f"总仓库数量: {response_dict['total_count']}")

    # 获取并打印返回的仓库列表长度
    repo_dicts = response_dict['items']
    print(f"返回的仓库数量: {len(repo_dicts)}")

    # 探索并打印第一个仓库的关键信息
    if repo_dicts:
        repo_dict = repo_dicts[0]
        print("\n第一个仓库的详细信息:")
        print(f"名称: {repo_dict['name']}")
        print(f"拥有者: {repo_dict['owner']['login']}")
        print(f"星星数: {repo_dict['stargazers_count']}")
        print(f"仓库URL: {repo_dict['html_url']}")
        print("\n所有键值对:")
        for key in sorted(repo_dict.keys()):
            print(key)
    else:
        print("没有返回任何仓库。")
# Out:
# 状态码: 200
# 总仓库数量: 12982400
# 返回的仓库数量: 10
#
# 第一个仓库的详细信息:
# 名称: langchain
# 拥有者: langchain-ai
# 星星数: 86725
# 仓库URL: https://github.com/langchain-ai/langchain
#
# 所有键值对:
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# topics
# trees_url
# updated_at
# url
# visibility
# watchers
# watchers_count
# web_commit_signoff_required

# %% [markdown]
# ### 17.1.6

# %%
# 研究有关仓库的信息
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}\n")

# 设置要显示的仓库数量上限（可根据需要调整）
max_repos_to_display = 10

print("Selected information about each repository:\n")
for index, repo_dict in enumerate(repo_dicts[:max_repos_to_display]):
    # 使用get方法安全访问字典，避免KeyError
    name = repo_dict.get('name', 'N/A')
    owner = repo_dict.get('owner', {}).get('login', 'N/A')
    stargazers_count = repo_dict.get('stargazers_count', 'N/A')
    html_url = repo_dict.get('html_url', 'N/A')
    description = repo_dict.get('description', 'N/A')
    
    # 整洁地打印每个仓库的信息
    print(f"Repository {index + 1}:")
    print(f"- Name: {name}")
    print(f"- Owner: {owner}")
    print(f"- Stars: {stargazers_count}")
    print(f"- Repository URL: {html_url}")
    print(f"- Description: {description}\n")
    
    # 如果达到显示上限，停止循环
    if index == max_repos_to_display - 1:
        break
# Out:
# Repositories returned: 30
#
# Selected information about each repository:
#
# Repository 1:
# - Name: public-apis
# - Owner: public-apis
# - Stars: 295536
# - Repository URL: https://github.com/public-apis/public-apis
# - Description: A collective list of free APIs
#
# Repository 2:
# - Name: langchain
# - Owner: langchain-ai
# - Stars: 86725
# - Repository URL: https://github.com/langchain-ai/langchain
# - Description: 🦜🔗 Build context-aware reasoning applications
#
# Repository 3:
# - Name: models
# - Owner: tensorflow
# - Stars: 76708
# - Repository URL: https://github.com/tensorflow/models
# - Description: Models and examples built with TensorFlow
#
# Repository 4:
# - Name: fastapi
# - Owner: tiangolo
# - Stars: 72295
# - Repository URL: https://github.com/tiangolo/fastapi
# - Description: FastAPI framework, high performance, easy to learn, fast to code, ready for production
#
# Repository 5:
# - Name: flask
# - Owner: pallets
# - Stars: 66744
# - Repository URL: https://github.com/pallets/flask
# - Description: The Python micro framework for building web applications.
#
# Repository 6:
# - Name: devops-exercises
# - Owner: bregman-arie
# - Stars: 64335
# - Repository URL: https://github.com/bregman-arie/devops-exercises
# - Description: Linux, Jenkins, AWS, SRE, Prometheus, Docker, Python, Ansible, Git, Kubernetes, Terraform, OpenStack, SQL, NoSQL, Azure, GCP, DNS, Elastic, Network, Virtualization. DevOps Interview Questions
#
# Repository 7:
# - Name: awesome-machine-learning
# - Owner: josephmisiti
# - Stars: 64028
# - Repository URL: https://github.com/josephmisiti/awesome-machine-learning
# - Description: A curated list of awesome Machine Learning frameworks, libraries and software.
#
# Repository 8:
# - Name: cpython
# - Owner: python
# - Stars: 60354
# - Repository URL: https://github.com/python/cpython
# - Description: The Python programming language
#
# Repository 9:
# - Name: gpt_academic
# - Owner: binary-husky
# - Stars: 60018
# - Repository URL: https://github.com/binary-husky/gpt_academic
# - Description: 为GPT/GLM等LLM大语言模型提供实用化交互接口，特别优化论文阅读/润色/写作体验，模块化设计，支持自定义快捷按钮&函数插件，支持Python和C++等项目剖析&自译解功能，PDF/LaTex论文翻译&总结功能，支持并行问询多种LLM模型，支持chatglm3等本地模型。接入通义千问, deepseekcoder, 讯飞星火, 文心一言, llama2, rwkv, claude2, moss等。
#
# Repository 10:
# - Name: manim
# - Owner: 3b1b
# - Stars: 58914
# - Repository URL: https://github.com/3b1b/manim
# - Description: Animation engine for explanatory math videos

# %% [markdown]
# ### 17.2 使用Pygal可视化仓库

# %%
import requests
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

# 定义API URL
URL = 'https://api.github.com/search/repositories?q=language:python&sort=stars'

try:
    # 执行API调用并存储响应
    response = requests.get(URL)
    response.raise_for_status()  # 检查请求是否成功
    print("Status code:", response.status_code)
except requests.RequestException as e:
    print(f"请求GitHub API时出错: {e}")
else:
    # 将API响应存储在一个变量中
    response_dict = response.json()
    print("Total repositories:", response_dict['total_count'])
    
    # 研究有关仓库的信息
    repo_dicts = response_dict['items']
    names, stars = [], []
    for repo_dict in repo_dicts:
        names.append(repo_dict['name'])
        stars.append(repo_dict['stargazers_count'])

    # 可视化
    print("正在创建条形图...")
    my_style = LS('#333366', base_style=LCS)
    chart = pygal.Bar(style=my_style, x_label_rotation=45, show_legend=False)
    chart.title = 'Most-Starred Python Projects on GitHub'
    chart.x_labels = names
    chart.add('', stars)
    
    try:
        # 渲染并保存图表到文件
        chart.render_to_file('python_repos.svg')
        print("条形图已保存至 python_repos.svg")
    except Exception as e:
        print(f"保存图表时出错: {e}")
# Out:
# Status code: 200
# Total repositories: 14043872
# 正在创建条形图...
# 条形图已保存至 python_repos.svg

# %% [markdown]
# ### 17.2.2 添加自定义工具提示

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

# 定义图表样式
my_style = LS('#333366', base_style=LCS)

# 创建条形图实例
chart = pygal.Bar(style=my_style, x_label_rotation=45, show_legend=False)
chart.title = 'Python Projects with Descriptions'

# 项目名称作为x轴标签
chart.x_labels = ['httpie', 'django', 'flask']

# 项目数据及描述
plot_dicts = [
    {'value': 16101, 'label': 'HTTPie - A command-line HTTP client, a user-friendly curl alternative with an intuitive UI and built-in JSON support.'},
    {'value': 15028, 'label': 'Django - A high-level Python web framework that encourages rapid development and clean, pragmatic design.'},
    {'value': 14798, 'label': 'Flask - A lightweight WSGI web application framework. It is designed to make getting started quick and easy, with the ability to scale up to complex applications.'},
]

# 添加数据到图表，注意plot_dicts已包含了value和自定义的描述信息
for data in plot_dicts:
    chart.add(data['label'], data['value'])

# 直接在控制台输出SVG内容，注释掉保存文件的行以满足“不要保存”的需求
print(chart.render(is_unicode=True))

# 注释掉以下行以避免保存文件
# chart.render_to_file('bar_descriptions.svg')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.4 (lxml) ©Kozea 2012-2016 on 2024-06-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2{background-color:#f8f8f8}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 path,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 rect,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 circle{-webkit-transition:250ms ease-in;-moz-transition:250ms ease-in;transition:250ms ease-in}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .graph &gt; .background{fill:#f8f8f8}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .plot &gt; .background{fill:#ffffff}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .graph{fill:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 text.no_data{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .title{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .legends .legend text{fill:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .legends .legend:hover text{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .line{stroke:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .guide.line{stroke:rgba(0,0,0,0.5)}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .major.line{stroke:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis text.major{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y .guides:hover .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .line-graph .axis.x .guides:hover .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .xy-graph .axis.x .guides:hover .guide.line{stroke:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .guides:hover text{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .reactive{fill-opacity:.5;stroke-opacity:.8;stroke-width:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .ci{stroke:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .reactive.active,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .active .reactive{fill-opacity:.9;stroke-opacity:.9;stroke-width:4}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .ci .reactive.active{stroke-width:1.5}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .series text{fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip rect{fill:#ffffff;stroke:#666;-webkit-transition:opacity 250ms ease-in;-moz-transition:opacity 250ms ease-in;transition:opacity 250ms ease-in}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .label{fill:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .label{fill:#333}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,0.5)}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .x_label{font-size:.6em;fill:#666}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip .value{font-size:1.5em}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .bound{font-size:.5em}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .max-value{font-size:.75em;fill:rgba(0,0,0,0.5)}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .map-element{fill:#ffffff;stroke:rgba(0,0,0,0.5) !important}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-0,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-0 a:visited{stroke:#333366;fill:#333366}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-1,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-1 a:visited{stroke:#3c3c79;fill:#3c3c79}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-2,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .color-2 a:visited{stroke:#46468c;fill:#46468c}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .text-overlay .color-0 text{fill:black}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .text-overlay .color-1 text{fill:black}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .text-overlay .color-2 text{fill:black}
# #chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 text.no_data{text-anchor:middle}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .guide.line{fill:none}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .centered{text-anchor:middle}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .title{text-anchor:middle}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .legends .legend text{fill-opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.x text{text-anchor:middle}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y text{text-anchor:end}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y text[transform].backwards{text-anchor:start}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y2 text{text-anchor:start}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y2 text[transform].backwards{text-anchor:end}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .horizontal .axis.y .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .horizontal .axis.y2 .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .vertical .axis.x .guide.line{opacity:0}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .horizontal .axis.always_show .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y .guides:hover .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.y2 .guides:hover .guide.line,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis.x .guides:hover .guide.line{opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .axis .guides:hover text{opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .nofill{fill:none}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .subtle-fill{fill-opacity:.2}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .dot.active{stroke-width:5px}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .dot.negative{fill:transparent}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 text,#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 tspan{stroke:none !important}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .series text.active{opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .tooltip text{fill-opacity:1}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .showable{visibility:hidden}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .showable.shown{visibility:visible}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .gauge-background{fill:rgba(229,229,229,1);stroke:none}#chart-a153ca73-7d6a-42c4-803b-98d2b6f19ae2 .bg-lines{stroke:#f8f8f8;stroke-width:2px}</style><script type="text/javascript">window.pygal = window.pygal || {};window.pygal.config = window.pygal.config || {};window.pygal.config['a153ca73-7d6a-42c4-803b-98d2b6f19ae2'] = {"allow_interruptions": false, "box_mode": "extremes", "classes": ["pygal-chart"], "css": ["file://style.css", "file://graph.css"], "defs": [], "disable_xml_declaration": false, "dots_size": 2.5, "dynamic_print_values": false, "explicit_size": false, "fill": false, "force_uri_protocol": "https", "formatter": null, "half_pie": false, "height": 600, "include_x_axis": false, "inner_radius": 0, "interpolate": null, "interpolation_parameters": {}, "interpolation_precision": 250, "inverse_y_axis": false, "js": ["//kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js"], "legend_at_bottom": false, "legend_at_bottom_columns": null, "legend_box_size": 12, "logarithmic": false, "margin": 20, "margin_bottom": null, "margin_left": null, "margin_right": null, "margin_top": null, "max_scale": 16, "min_scale": 4, ...

# %% [markdown]
# ### 17.2.3 根据数据绘图

# %%
# 研究有关仓库的信息
repo_dicts = response_dict['items']
print("Number of items:", len(repo_dicts))

# 初始化名字列表和图表数据列表
names, plot_dicts = [], []

# 遍历仓库字典列表
for repo_dict in repo_dicts:
    # 添加仓库名到names列表
    names.append(repo_dict['name'])
    
    # 创建包含星标数和描述的字典，并添加到plot_dicts列表
    plot_dict = {
        'value': repo_dict['stargazers_count'],
        'label': repo_dict['description'],
    }
    plot_dicts.append(plot_dict)

# 可视化
my_style = LS('#333366', base_style=LCS)
chart = pygal.Bar(style=my_style, x_label_rotation=45, show_legend=False)
chart.title = 'Python Repositories by Star Count'

# 设置x轴标签
chart.x_labels = names

# 将plot_dicts数据添加到图表
chart.add('', plot_dicts)

# 渲染图表并保存到文件
chart.render_to_file('python_repos.svg')
# Out:
# Number of items: 30
